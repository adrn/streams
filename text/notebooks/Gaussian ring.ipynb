# %%
t = (97.)*np.pi/180.
print np.sin(t), np.cos(t)

a = np.cos((45.)*np.pi/180.)
b = np.cos((135)*np.pi/180.)

print a,b

figure()
xxx = hist(180/np.pi*np.arccos(np.random.uniform(a, b, size=100000)), bins=50)
# Out:
# 0.992546151641 -0.121869343405
# 0.707106781187 -0.707106781187

# %%
import os
from streams.io.sgr import SgrSimulation
from streams.integrate import LeapfrogIntegrator
from streams.potential.lm10 import LawMajewski2010

# %%
def gaussian(x, mu, sigma):
    return 1./np.sqrt(2*np.pi*sigma**2) * np.exp(-0.5 * ((x-mu)/sigma)**2)

# %%
N = 5000
_m = "2.5e8"
m = float(_m)
sgr = SgrSimulation(_m)

# %%
p = sgr.particles(N=N, expr="tub!=0")
p_bound = sgr.particles(N=0, expr="tub==0")

# %%
p2 = sgr.particles(N=N, expr="(tub!=0) & (tub<{})".format((5000*u.Myr).to(sgr.particle_units[0]/sgr.particle_units[-1]).value))
x,bins,pat = hist(p.tub, bins=50, alpha=0.5)
zsdfj = hist(p2.tub, bins=bins, alpha=0.5)

# %%
v_disp = np.sqrt(np.var(p_bound["vx"]) + np.var(p_bound["vy"]) + np.var(p_bound["vz"])).value[0]
v_disp
# Out:
# 0.017198632324974907

# %%
s = sgr.satellite()

# %%
figure(figsize=(6,6))
plot(p._X[:,0],p._X[:,2],marker='o',linestyle='none',alpha=0.1,ms=10)

# %%
lm10_potential = LawMajewski2010()

# %%
X = np.vstack((s._X[...,:3], p._X[...,:3].copy()))
V = np.vstack((s._X[...,3:], p._X[...,3:].copy()))
integrator = LeapfrogIntegrator(lm10_potential._acceleration_at,
                                np.array(X), np.array(V),
                                args=(X.shape[0], np.zeros_like(X)))
ts, rs, vs = integrator.run(t1=sgr.t1, t2=sgr.t2, dt=-1.)

# %%
s_orbit = np.vstack((rs[:,0][:,np.newaxis].T, vs[:,0][:,np.newaxis].T)).T
p_orbits = np.vstack((rs[:,1:].T, vs[:,1:].T)).T
t_idx = np.array([np.argmin(np.fabs(ts - t)) for t in p.tub])

# %%
p_x = np.array([p_orbits[jj,ii] for ii,jj in enumerate(t_idx)])
s_x = np.array([s_orbit[jj,0] for jj in t_idx])

# %%
diff = p_x-s_x
rel_r = np.sqrt(np.sum(diff[:,:3]**2, axis=-1))
rel_v = np.sqrt(np.sum(diff[:,3:]**2, axis=-1))

# %%
r_tide = lm10_potential._tidal_radius(m, s_x)*1.6
v_esc = lm10_potential._escape_velocity(m, r_tide)

# %%
sat_r_tide = np.squeeze(lm10_potential._tidal_radius(m, s_orbit))*1.6

# %%
full_diff = p_orbits-s_orbit
full_rel_r = np.sqrt(np.sum(full_diff[...,:3]**2, axis=-1))
full_rel_v = np.sqrt(np.sum(full_diff[...,3:]**2, axis=-1))

# %%
full_D_ps = np.sqrt((full_rel_r/sat_r_tide[:,np.newaxis])**2 + (full_rel_v/v_disp)**2)
D_ps = np.min(full_D_ps, axis=0)

# %%
sum(D_ps < 2.) / float(N)
# Out:
# 0.98919999999999997

# %% [markdown]
# ----

# %%
from astropy.coordinates import Angle

# %%
r = np.sqrt(diff[:,2]**2 + diff[:,0]**2)
theta = Angle(np.arctan2(diff[:,2],diff[:,0])*u.rad)
new_theta = theta.wrap_at(90*u.deg)

# %%
fig,axes = plt.subplots(1,2,figsize=(12,5))
axes[0].plot(new_theta.degree, np.log(r), marker='o', linestyle='none', alpha=0.1, ms=6)
axes[0].axhline(np.log(r_tide.mean()), alpha=0.5, lw=3., color='b')
xxz = axes[1].hist(np.log(r), orientation='horizontal', bins=50, alpha=0.5)

# %%
figure(figsize=(5,5))
plot(diff[:,0]/r_tide.mean(), diff[:,2]/r_tide.mean(), marker='o', linestyle='none', alpha=0.1, ms=6)
xlim(-3,3)
ylim(*xlim())
# Out:
# (-3.0, 3.0)

# %%
from tempfile import NamedTemporaryFile

VIDEO_TAG = """<video controls>
 <source src="data:video/x-m4v;base64,{0}" type="video/mp4">
 Your browser does not support the video tag.
</video>"""

def anim_to_html(anim):
    if not hasattr(anim, '_encoded_video'):
        with NamedTemporaryFile(suffix='.mp4') as f:
            anim.save(f.name, fps=20, extra_args=['-vcodec', 'libx264'])
            video = open(f.name, "rb").read()
        anim._encoded_video = video.encode("base64")
    
    return VIDEO_TAG.format(anim._encoded_video)

# %%
from IPython.display import HTML

def display_animation(anim):
    plt.close(anim._fig)
    return HTML(anim_to_html(anim))

# %%
idxx = np.ones(full_D_ps.shape[1]).astype(bool)
idx = []
for i in range(full_D_ps.shape[0]):
    idxx = idxx & (full_D_ps[i] > 2.)
    idx.append(idxx.copy())
idx = np.array(idx)

# %%
from matplotlib import animation
from matplotlib.patches import Circle

# First set up the figure, the axis, and the plot element we want to animate
fig = plt.figure(figsize=(8,8))
#ax = plt.axes(xlim=(-75, 75), ylim=(-75, 75))
ax = plt.axes(xlim=(-100, 100), ylim=(-100, 100))
line_p, = ax.plot([], [], linestyle='none', marker='.', alpha=0.1, ms=10.)
#line_s, = ax.plot([], [], linestyle='none', marker='o', alpha=0.75, color='#ca0020')
circ_s = Circle((0., 0.), radius=0., color='#ca0020', alpha=0.5)
ax.add_patch(circ_s)
ax.set_xlabel(r"$X_{\rm GC}-X_{\rm sat}$ [kpc]")
ax.set_ylabel(r"$Z_{\rm GC}-Z_{\rm sat}$ [kpc]")
              
# initialization function: plot the background of each frame
def init():
    line_p.set_data([], [])
    circ_s.center = (0.,0.)
    circ_s.set_radius(0.)
    return line_p,circ_s

speedup = 5
# animation function.  This is called sequentially
def animate(ii):
    i = ii*speedup
    line_p.set_data(full_diff[i,idx[i],0], full_diff[i,idx[i],2])
    #line_s.set_data(s_orbit[i,0,0], s_orbit[i,0,2])
    circ_s.center = (0.,0.)
    circ_s.set_radius(sat_r_tide[i])
    ax.set_title("{:.2f} Myr".format(ts[i]))
    return line_p,circ_s

# call the animator.  blit=True means only re-draw the parts that have changed.
frames = full_diff.shape[0]//speedup
anim = animation.FuncAnimation(fig, animate, init_func=init,
                               frames=frames, interval=20, blit=True) # frame=6248

# call our new function to display the animation
display_animation(anim)
# Out:
# <video controls>
#  <source src="...

# %% [markdown]
# ----

# %%
figsize(11,8)
subplot(121)
title("relative velocity distribution")

#bins = np.logspace(-3, 0, 50)
#xscale('log')
bins = np.linspace(-1e0, 1e0, 100)

xxx = hist(rel_v, bins=bins)
axvline(v_esc.mean(), color='r', label='mean escape velocity')
xlabel(r"$V_{i,sat}$")
legend()

subplot(122)
title("relative distance distribution")

#bins = np.logspace(-1, 2, 50)
#xscale('log')
bins = np.linspace(-1e2, 1e2, 100)

xxx = hist(rel_r, bins=bins)
axvline(r_tide.mean(), color='r', label='mean tidal radius')
xlabel(r"$D_{i,sat}$")
legend()

# %%
figsize(11,8)
title("relative velocity distribution")

bins = np.logspace(-3, 0, 50)
xscale('log')
#bins = np.linspace(1e-4, 1e0, 100)

xxx = hist(rel_v, bins=bins, alpha=0.5)
axvline(v_esc.mean(), color='r', label='mean escape velocity')
xlabel(r"$V_{i,sat}$")

# %%
figsize(11,8)
title("distance distribution")

bins = np.logspace(-1, 2, 50)
xscale('log')

xxx = hist(rel_r, bins=bins, alpha=0.4)
axvline(np.mean(r_tide), color='#ca0020', label='mean tidal radius', lw=2., alpha=0.75)
xlabel(r"$D_{i,sat}$")
title("relative distance distribution")

# %%
print np.log(r_tide.mean()), np.mean(np.log(r_tide))
print np.log(v_esc.mean()), np.log(v_disp)
# Out:
# 1.67533510752 1.58549110401
# -4.59815359603 -4.06292541431

# %%
nbins = 50
fig,axes = plt.subplots(1,2,figsize=(16,8))

n,bins,patches = axes[0].hist(np.log(rel_r), bins=nbins, alpha=0.4, normed=True)
axes[0].plot(bins, gaussian(bins, np.log(r_tide.mean()), 0.45))
axes[0].axvline(np.log(r_tide.mean()), color='#ca0020', lw=2., alpha=0.75, label=r'$\log \langle R_{\rm tide}\rangle$')
axes[0].set_xlabel(r"$\log D_{i,s}$")
axes[0].set_title("relative distance distribution")
axes[0].legend()
axes[0].set_yticks([])

n,bins,patches = axes[1].hist(np.log(rel_v), bins=nbins, alpha=0.4, normed=True)
#axes[1].plot(bins, gaussian(bins, np.log(v_esc.mean()), 0.6))
axes[1].plot(bins, gaussian(bins, np.log(v_disp), 0.6))
#axes[1].axvline(np.log(v_esc.mean()), color='#ca0020', lw=2., alpha=0.75, label=r'$\log \langle V_{\rm esc}\rangle$')
axes[1].axvline(np.log(v_disp), color='#ca0020', lw=2., alpha=0.75, label=r'$\log \langle V_{\rm esc}\rangle$')
axes[1].set_xlabel(r"$\log V_{i,s}$")
axes[1].set_title("relative velocity distribution")
axes[1].legend()
axes[1].set_yticks([])

plt.tight_layout()

# %%
R = rel_r
lnR = np.log(rel_r)

mu_r = np.log(r_tide)
sigma_r = 0.55
r_term = -0.5*(2*np.log(sigma_r) + ((lnR-mu_r)/sigma_r)**2) - np.log(R**3)

# ------------------------------------------------------------------------

V = rel_v
lnV = np.log(rel_v)

mu_v = np.log(v_disp)
sigma_v = 0.8
v_term = -0.5*(2*np.log(sigma_v) + ((lnV-mu_v)/sigma_v)**2) - np.log(V**3)

plot(r_term, v_term, linestyle='none', marker='.', alpha=0.5)

# %%
nbins = 50
fig,ax = plt.subplots(1,1,figsize=(8,8))
n,bins,patches = ax.hist(-0.5*(2*np.log(sigma_r) + (np.log(rel_r) - np.mean(np.log(r_tide))) / sigma_r) - np.log(rel_r**3), bins=nbins, alpha=0.4, normed=True)
n,bins,patches = ax.hist(-0.5*(2*np.log(sigma_v) + (np.log(rel_v) - np.log(v_disp)) / sigma_v) - np.log(rel_v**3), bins=nbins, alpha=0.4, normed=True)

#ax.set_xlabel(r"$\log D_{i,s}$")
ax.set_title("norm. relative distance distribution")
ax.set_yticks([])

plt.tight_layout()

# %% [markdown]
# ---

# %%
from scipy.stats import norm, lognorm, chi

print norm.fit(np.log(rel_r))[0], np.log(r_tide.mean())
print norm.fit(np.log(rel_v))[0], np.log(v_esc.mean())
# Out:
# 1.58801598543 1.6453765317
# -4.00469931934 -4.30172574458

# %%
print lognorm.fit(rel_r)
print lognorm.fit(rel_v)
#print norm.fit(np.log(rel_v))[0], np.log(v_esc.mean())
# Out:
# (1.0, 2.0440159626117382, 2.2426522265124449)
# (1.0, 0.0028242259343718018, 0.013776979682551644)
# /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/scipy/optimize/optimize.py:447: RuntimeWarning: invalid value encountered in subtract
#   and max(abs(fsim[0] - fsim[1:])) <= ftol):

# %%
(np.log(rel_r) - np.log(r_tide))/np.log(r_tide)
# Out:
# array([ -1.23178963e-01,   1.06593927e-01,   2.77877572e-02,
#          2.46901170e-01,  -2.78822163e-01,  -1.88861978e-01,
#         -5.54200132e-01,  -3.74150068e-01,   6.58515844e-01,
#         -2.37428114e-01,   8.20412054e-01,   1.33820731e-01,
#         -3.81376340e-02,  -2.34698664e-01,  -2.09463727e-01,
#          5.95881329e-01,  -1.47710077e-01,  -1.62973146e-01,
#         -1.45808687e-01,  -6.24868704e-02,   1.25803890e+00,
#          7.04900206e-01,   8.67465977e-02,   1.43912912e-01,
#          3.96626834e-01,   5.61211954e-03,   5.88208639e-01,
#         -1.85481763e-01,   4.33446801e-01,   1.12020606e-01,
#          1.62431367e+00,   3.97301725e-01,  -8.03219824e-02,
#         -1.90135896e-01,  -1.71716014e-01,   4.50174765e-01,
#          4.18192592e-01,  -4.63370883e-02,   7.69874030e-02,
#          2.58818084e-01,   9.54758617e-01,   1.46363869e-02,
#         -2.06053364e-01,   1.31617257e+00,  -3.80800021e-01,
#          8.61489998e-02,  -3.22765412e-02,   5.96154848e-02,
#         -5.17726766e-02,  -2.82556079e-01,  -4.72965722e-01,
#         -1.32433819e-01,  -1.66712272e-01,   5.00972627e-01,
#          2.04037610e-01,   1.42833137e+00,   6.70956337e-02,
#         -1.60571952e-01,  -1.83708322e-01,  -6.69302047e-02,
#         -1.48247995e-01,   1.57333515e-02,   6.50927761e-02,
#         -2.14653616e-01,   2.77305032e-01,  -1.62016261e-01,
#         -1.18408085e-01,  -1.60841665e-01,  -1.65082677e-01,
#          2.32746869e+00,  -1.52869199e-01,   5.13421784e-01,
#         -7.60328649e-02,  -2.69012894e-01,   6.12721357e-02,
#         -2.09599413e-01,   1.89897749e-02,   4.27585687e-02,
#          4.50878677e-02,  -2.95785281e-01,   8.53624626e-01,
#          7.95922944e-02,   1.50170557e-01,   7.98010215e-01,
#         -3.67458352e-01,   3.42000323e-01,  -1.10868447e-01,
#         -1.47971939e-01,  -4.45621589e-01,  -3.96031779e-01,
#          3.08057566e-01,   1.07411019e-01,   9.39112122e-01,
#        -0.09730761, -0.26705401, -0.07338315,  0.03437736, -0.05928394,
#        -0.39208108,  0.15927855, -0.16057607,  0.09894758, -0.02473456,
#         0.09330066,  0.30885774,  0.06982613, -0.01028323,  0.17486579,
#        -0.05190956, -0.01687417,  0.00247559, -0.09676043, -0.27640053,
#        -0.41885173,  0.10130498, -0.00247778,  0.01033415, -0.048347  ,
#         0.34590559, -0.0048008 , -0.01211586,  0.08244265,  0.07519972,
#        -0.11082629,  0.13862145, -0.11685909,  0.3629658 , -0.19917981,
#        -0.39197781, -0.00421723, -0.03943732,  0.09505577, -0.07533769,
#         0.20229915,  0.10570555, -0.0655198 , -0.12796377,  0.10257994,
#        -0.13772861,  0.14234013, -0.27026696, -0.0935299 ,  0.27208237,
#        -0.17768618,  0.15503962, -0.28231618, -0.05066492,  0.49848126,
#        -0.08605336, -0.10832416, -0.59800496,  0.07845872,  0.0138182 ,
#        -0.049399  , -0.19820776, -0.25057374, -0.22151405,  0.3786394 ,
#         0.10177068, -0.21034026, -0.14847603, -0.0509527 , -0.38088845,
#         0.28210893, -0.02378592,  0.1373277 , -0.03295068, -0.0825814 ,
#         0.14478027,  0.0747219 ,  0.43986868, -0.0678793 ,  0.12571606])

# %%
# TODO DON'T USE MEAN HERE?
nbins = 50
fig,axes = plt.subplots(1,2,figsize=(16,8))

bins = np.linspace(-2.,2.,nbins)
n,bins,patches = axes[0].hist((np.log(rel_r) - np.log(r_tide)), bins=bins, alpha=0.4, normed=True)
axes[0].set_title("relative distance distribution")
axes[0].set_yticks([])
axes[0].set_xlim(-2.,2.)

n,bins,patches = axes[1].hist((np.log(rel_v) - np.log(v_disp)), bins=bins, alpha=0.4, normed=True)
axes[1].set_title("relative velocity distribution")
axes[1].set_yticks([])
axes[1].set_xlim(-2.,2.)

plt.tight_layout()

# %%
# fit disruption radius / mean tidal radius
mass = [2.5e6, 2.5e7, 2.5e8, 2.5e9]

norm_r = [0.0724845573905/0.129291731281, 
          0.895259956901/0.906689979317,
          1.60371774159/1.67602532102,
          2.7243176297/2.40713745933]

# fit disruption velocity / mean escape velocity
norm_v = [-5.52845243206/-5.57172716011,
          -4.6582018788/-5.09398177463,
          -4.05684157145/-4.59797274877,
          -2.6682475788/-4.0811703757]

subplot(211)
loglog(mass, norm_r, marker='o')
ylim(0.5, 1.5)

subplot(212)
m = -0.06
b = 0.93
plot(np.log(mass), np.log(norm_v), marker='o')
plot(np.log(mass), m*np.log(mass)+b,marker='o')
#ylim(0.5, 1.5)

# %% [markdown]
# ----

# %% [markdown]
# How do stars leak out of a disrupting satellite?

# %%
from astropy.constants import G

# %%
r = np.linspace(-2., 10., 250)*u.kpc

M = 1E12*u.M_sun
m = 0.01*M
r1 = 0.*u.kpc
r2 = 5*u.kpc
r_tide = 0.794*(m/M)**0.33333333*(r2-r1)

# %%
phi = -G*(M/np.fabs(r-r1) + m/np.fabs(r-r2))

figure(figsize=(12,6))
semilogy(r.value, -phi.value)
axvline(r2.value, alpha=0.5)
axvline((r2+r_tide).value, linestyle='--')
axvline((r2-r_tide).value, linestyle='--')
