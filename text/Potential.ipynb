# %%
import streams.potential as sp
import astropy.units as u

# %%
disk_pot = sp.MiyamotoNagaiPotential(a=6.5, b=0.26, M=1E10*u.solMass)
grid = np.arange(-12., 12., 100)
disk_pot.plot(grid, grid, grid)
# Out:
# (<matplotlib.figure.Figure at 0x10399ef90>,
#  array([[Axes(0.08,0.509524;0.390476x0.390476),
#         Axes(0.509524,0.509524;0.390476x0.390476)],
#        [Axes(0.08,0.08;0.390476x0.390476),
#         Axes(0.509524,0.08;0.390476x0.390476)]], dtype=object))

# %%
sp.HernquistPotential(c=12., M_spher=1E9*u.solMass)
# Out:
# $\Phi_{spher} = -\frac{GM_{spher}}{r + c}$

# %%
log_pot = sp.LogarithmicPotential(c=12., p=1., q=0.5, v_circ=180*u.km/u.s)

# %%
log_pot.add_component("disk")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-f0ab2daf94c4> in <module>()
# ----> 1 log_pot.add_component("disk")
#
# /Users/adrian/projects/streams/streams/potential/common.py in <lambda>(*args)
#     192
#     193         self.add_component("halo", f_derivs[0], derivs=f_derivs[1:])
# --> 194         self.add_component = lambda *args: _raise(AttributeError("'add_component' is only available for the base Potential class."))
#     195         self._latex = None
#     196
#
# /Users/adrian/projects/streams/streams/potential/common.py in _raise(ex)
#      20
#      21 def _raise(ex):
# ---> 22     raise ex
#      23
#      24 ####################################################################################
#
# AttributeError: 'add_component' is only available for the base Potential class.
# ...

# %%
grid = np.linspace(-40., 40., 100)
log_pot.plot(grid, grid, grid)
# Out:
# (<matplotlib.figure.Figure at 0x10faa97d0>,
#  array([[Axes(0.075,0.530952;0.416667x0.369048),
#         Axes(0.533333,0.530952;0.416667x0.369048)],
#        [Axes(0.075,0.125;0.416667x0.369048),
#         Axes(0.533333,0.125;0.416667x0.369048)]], dtype=object))
